# %% [markdown]
# # Transformers for Reinforcement Learning - Analysis
#
# This notebook demonstrates the analysis capabilities of the Transformers for RL framework.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

import numpy as np
import matplotlib.pyplot as plt
import torch
import gymnasium as gym

from models.decision_transformer import DecisionTransformer
from models.trajectory_transformer import TrajectoryTransformer
from utils.device import get_device, set_seed
